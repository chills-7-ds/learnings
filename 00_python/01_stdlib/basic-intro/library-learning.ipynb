# %%
# In this, we are going to cover standard libraries.

"""
The standard library is a collection of pre-installed modules and packages that come with Python. 
It provides a wide range of functionality, such as file I/O, math operations, data manipulation, and more.
It includes modules like math, os, sys, datetime, json, etc.
Standard libraries that i thought of covering for now are : datetime, os, argparse, sys, re, random & secrets, hashlib, time, collections, itertools & functools, json & csv & pickle and logging.
"""

# Modules are Python files that contain reusable code, while libraries are collections of modules that provide specific functionality.

# standard libraries dont require any pip installations just simply use this syntax
import module_name
# they come bundled with python

"""
Key Differences

Scope: A module is a single file, while a library is a collection of multiple modules and packages.

Purpose: Modules are used to organize and reuse code within a specific context, whereas libraries provide a broader set of functionalities that can be used across different applications.

Structure: Modules are simple files with a .py extension, while libraries can contain multiple modules, packages, and sub-packages.
"""

"""
When you install Python (say, Python 3.11), it already includes a huge toolbox—the Standard Library. 
These are “batteries included” modules: tested, optimized, and trusted. You don’t need to reach out to the internet for them.
"""

# Modules and packages are parts of Python’s structure. 
"""
I covered these modules and packages in basics folder which you can check in these, - """https://github.com/chills-7-ds/python-crafting-grounds/tree/main/00_basics
"""where i did projects covering the concepts of modules and packages and """https://github.com/chills-7-ds/learnings/tree/main/00_python/00_basics

# wherein you will find the jupyter notebook which has the modules and packages in theory.
# The Standard Library is a collection of built-in modules and packages that come with Python.

import math
print(math.sqrt(16))  # Output: 4.0
 
# a quick example of using the standard library math is seen above.
# this standard library "math" has in-built functions 
"""The math module in Python’s standard library gives you access to fast, low-level mathematical functions—like square roots, trigonometry, logarithms, 
constants like π and e."""

# tools:
math.sqrt(25) # → 5.0

math.floor(4.7) # → 4

math.log(10, 10) # → 1.0

math.pow(2, 3) # → 8.0

math.pi, math.e # → constants

# %%
# that was the basic intro now let's move to other standard libraries. 
"https://github.com/chills-7-ds/learnings" 
in this link above, find the folder named "00_python" then once you click it find another folder named "01_stdlib". 

# there u will find folders named after stdlib's and you can click on the ones you are interested in (datetime, os or argparse etc)
#i covered the theory and a bit of practice in that, so do check it out!

if you are looking for the projects i did, do check out this link : "https://github.com/chills-7-ds/python-crafting-grounds/tree/main/01_stdlib"
