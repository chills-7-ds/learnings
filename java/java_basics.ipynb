# %%
#JAVA

# %%
""" 
Java is a technology to develop applications to resolve real world problems and to make our lives easier.
for example, messenger applications and phone-pay applications are developed using Java.
"""

# we tell our requirement to OS but it speaks in binary so java compiler converts our code to binary language.

"""
Programs are a set of instructions that tell the computer what to do.
Instructions are a set of rules that the computer follows to perform a task.
rules are a set of syntaxes that the computer understands.
through these programs, we can communicate with the computer and tell it what to do.
set of programs is called a application.
"""

# if it is high level language, it is easy to understand and write by humans.
# if it is low level language, it is easy to understand and write by computers.
# if it is middle level language, it contains bytecodes.

"java is a high level OOP language where we are correlating with real world entities."
# OOP is Object Oriented Programming.
# OOP is a programming paradigm that uses objects and classes to structure the code.
# OOP is a way of organizing code that makes it easier to understand and maintain.

"""
java is a platform independent language.
Platform independence means that the code can run on any operating system without modification.
Java achieves this by compiling the code into bytecode, which can be executed by the Java Virtual Machine (JVM).
Java is a compiled language, which means that the code is translated into machine code before it is executed.
Java is an interpreted language, which means that the code is executed line by line at runtime.
Java is a case sensitive language.
Java is a strongly typed language, which means that variables must be declared with a specific data type.
Java is a multi-threaded language, which means that it can execute multiple threads of execution simultaneously.
Java is a garbage collected language, which means that it automatically manages memory allocation and deallocation.
Java is a secure language, which means that it has built-in security features to protect against malicious code.
Java is a robust language, which means that it has strong error handling and exception handling features.
Java is a portable language, which means that it can run on any platform that has a JVM installed.
Java is a dynamic language, which means that it can adapt to changes at runtime.
Java is a high level language, which means that it is easy to read and write by humans.
"""

# real time objects have state, behavior and identity.
# state is the data that the object holds.
# behavior is the actions that the object can perform.
# identity is the unique identifier of the object.

""" 

Java is a class based language.
A class is a blueprint for creating objects.
A class defines the state and behavior of an object.
A class can have fields (variables) and methods (functions).
A class can also have constructors, which are special methods that are called when an object is created.
A class can inherit from another class, which means that it can use the fields and methods of the parent class.
A class can implement interfaces, which are contracts that define a set of methods that the class must implement.
An interface is a collection of abstract methods that a class can implement.
An abstract class is a class that cannot be instantiated, but can be subclassed.
An abstract method is a method that is declared without an implementation.
A package is a collection of related classes and interfaces.
A package is used to organize classes and interfaces into namespaces.
A Java program is a collection of classes and interfaces.
A Java program must have a main method, which is the entry point of the program.
A Java program can have multiple classes and interfaces.
A Java program can be compiled into bytecode, which can be executed by the JVM.
A Java program can be executed on any platform that has a JVM installed.
A Java program can be run from the command line or from an IDE (Integrated Development Environment).
"""

# let's talk a bit about the Java Development Kit (JDK) and Java Runtime Environment (JRE).
"""
JDK is a software development kit that provides tools for developing Java applications. 
It is a combination of JRE and development tools such as jar files, libraries, and compilers.

JRE is a runtime environment that provides the necessary libraries and components to run Java applications.
It is a combination of the Java Virtual Machine (JVM) and the JIT compiler which provides runtime support for Java applications.

JVM is a virtual machine that executes Java bytecode.
JIT (Just-In-Time) compiler is a component of the JVM that compiles bytecode into native machine code at runtime for better performance.
"""

# how do you save a java file?
"""
Java files are saved with the .java extension.
The file name must match the class name defined in the file.
For example, if the class name is MyClass, the file name must be MyClass.java.
When you compile the Java file, it generates a .class file with the same name as the class.
The .class file contains the bytecode that can be executed by the JVM.
To compile a Java file, you can use the javac command followed by the file name.
For example, to compile MyClass.java, you would run:
javac MyClass.java
To run the compiled Java program, you can use the java command followed by the class name (without the .class extension).
For example, to run MyClass, you would run:
java MyClass

To run a Java program, you need to have the JRE installed on your system.
To check if Java is installed, you can run the command:
java -version
If Java is installed, it will display the version information.
If Java is not installed, you can download and install the JDK from the official Oracle website or from other sources.
To set up the Java environment, you need to set the JAVA_HOME environment variable to the JDK installation directory.
You also need to add the JDK bin directory to the PATH environment variable.
To set the JAVA_HOME variable on Windows, you can follow these steps:
1. Right-click on "This PC" or "Computer" and select "Properties".
2. Click on "Advanced system settings".
3. Click on the "Environment Variables" button.
4. Under "System variables", click on "New" and enter "JAVA_HOME" as the variable name and the path to the JDK installation directory as the variable value.
5. Click "OK" to save the changes.
To set the PATH variable on Windows, you can follow these steps:
1. In the same "Environment Variables" window, find the "Path" variable under "System variables".
2. Select it and click on "Edit".
3. Click on "New" and add the path to the JDK bin directory (e.g., C:\Program Files\Java\jdk-<version>\bin).
4. Click "OK" to save the changes.

After making these changes, you need to restart your terminal or run the command source <shell_config_file> to apply the changes.

"""
